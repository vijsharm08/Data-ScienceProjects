# %% [markdown]
# # Activity 3.01

# %% [markdown]
# #### Import required packages for this excercise and read data through Boston Housing file.
#
# #### Just adding one panda package to ignore warnings
#
# #### after adding packages calling Boston housing file for this week excercise

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# %%
df=pd.read_csv("./Boston_housing.csv")

# %% [markdown]
# #### Show top 10 records from the Boston housing file

# %%
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# ...

# %% [markdown]
# #### Get the dimension of dataframe

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# #### Get the selected attributes from dataframe and get last 10 records from it.

# %%
selectedf = df[['CRIM','ZN','INDUS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','PRICE']]

# %%
selectedf.tail(10)
# Out:
#         CRIM   ZN  INDUS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 496  0.28960  0.0   9.69  0.585  5.390  72.9  2.7986    6  391     19.2   19.7
# 497  0.26838  0.0   9.69  0.585  5.794  70.6  2.8927    6  391     19.2   18.3
# 498  0.23912  0.0   9.69  0.585  6.019  65.3  2.4091    6  391     19.2   21.2
# 499  0.17783  0.0   9.69  0.585  5.569  73.5  2.3999    6  391     19.2   17.5
# 500  0.22438  0.0   9.69  0.585  6.027  79.7  2.4982    6  391     19.2   16.8
# 501  0.06263  0.0  11.93  0.573  6.593  69.1  2.4786    1  273     21.0   22.4
# 502  0.04527  0.0  11.93  0.573  6.120  76.7  2.2875    1  273     21.0   20.6
# 503  0.06076  0.0  11.93  0.573  6.976  91.0  2.1675    1  273     21.0   23.9
# 504  0.10959  0.0  11.93  0.573  6.794  89.3  2.3889    1  273     21.0   22.0
# 505  0.04741  0.0  11.93  0.573  6.030  80.8  2.5050    1  273     21.0   11.9

# %% [markdown]
# #### Plot the different histograms based on different attrubutes from selected dataframe

# %%
for c in selectedf.columns:
    plt.title("Plot of "+c,fontsize=15)
    plt.hist(selectedf[c],bins=20)
    plt.show()

# %% [markdown]
# ### scatter plot for crime rate vs price

# %%
plt.scatter(selectedf['CRIM'],selectedf['PRICE'])
plt.show()

# %% [markdown]
# #### Get the type of multiline data

# %%
plt.scatter(np.log10(selectedf['CRIM']),selectedf['PRICE'],c='purple')
plt.title("Crime rate (Log) vs. Price plot", fontsize=18)
plt.xlabel("Log of Crime rate",fontsize=15)
plt.ylabel("Price",fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# #### Mean values calculation for different attributes

# %%
selectedf['RM'].mean()
# Out:
# 6.284634387351779

# %%
selectedf['AGE'].median()
# Out:
# 77.5

# %%
selectedf['DIS'].mean()
# Out:
# 3.795042687747036

# %% [markdown]
# #### Houses priced below 50,000. So below are the details.

# %%
low_price=selectedf['PRICE']<50
print(low_price)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 501    True
# 502    True
# 503    True
# 504    True
# 505    True
# Name: PRICE, Length: 506, dtype: bool

# %% [markdown]
# #### Mean values of the low prices <50

# %%
low_price.mean()
# Out:
# 0.9683794466403162

# %% [markdown]
# #### convert that into percentage by multiplying with 100

# %%
pcnt=low_price.mean()*100
print("\nPercentage of house with <20,000 price is: ",pcnt)
# Out:
# Percentage of house with <20,000 price is:  96.83794466403161

# %% [markdown]
# # Activity 4.01

# %% [markdown]
# #### loading adult income file and getting valuable information out of it.

# %%
df = pd.read_csv("./adult_income_data.csv")
df.head(10)
# Out:
#    39          State-gov   77516      Bachelors  13           Never-married  \
# 0  50   Self-emp-not-inc   83311      Bachelors  13      Married-civ-spouse
# 1  38            Private  215646        HS-grad   9                Divorced
# 2  53            Private  234721           11th   7      Married-civ-spouse
# 3  28            Private  338409      Bachelors  13      Married-civ-spouse
# 4  37            Private  284582        Masters  14      Married-civ-spouse
# 5  49            Private  160187            9th   5   Married-spouse-absent
# 6  52   Self-emp-not-inc  209642        HS-grad   9      Married-civ-spouse
# 7  31            Private   45781        Masters  14           Never-married
# 8  42            Private  159449      Bachelors  13      Married-civ-spouse
# 9  37            Private  280464   Some-college  10      Married-civ-spouse
#
#          Adm-clerical   Not-in-family     Male   2174  0  40   United-States  \
# ...

# %%
names = []
with open('./adult_income_names.txt','r') as f:
    for line in f:
        f.readline()
        var=line.split(":")[0]
        names.append(var)
names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %%
names.append('Income')

# %%
df = pd.read_csv("./adult_income_data.csv",names=names)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# #### Make a list of all variables with classes

# %%
vars_class = ['workclass','education','marital-status',
              'occupation','relationship','sex','native-country']

# %%
for v in vars_class:
    classes=df[v].unique()
    num_classes = df[v].nunique()
    print("There are {} classes in the \"{}\" column. They are: {}".format(num_classes,v,classes))
    print("-"*100)
# Out:
# There are 9 classes in the "workclass" column. They are: [' State-gov' ' Self-emp-not-inc' ' Private' ' Federal-gov' ' Local-gov'
#  ' ?' ' Self-emp-inc' ' Without-pay' ' Never-worked']
# ----------------------------------------------------------------------------------------------------
# There are 16 classes in the "education" column. They are: [' Bachelors' ' HS-grad' ' 11th' ' Masters' ' 9th' ' Some-college'
#  ' Assoc-acdm' ' Assoc-voc' ' 7th-8th' ' Doctorate' ' Prof-school'
#  ' 5th-6th' ' 10th' ' 1st-4th' ' Preschool' ' 12th']
# ----------------------------------------------------------------------------------------------------
# There are 7 classes in the "marital-status" column. They are: [' Never-married' ' Married-civ-spouse' ' Divorced'
#  ' Married-spouse-absent' ' Separated' ' Married-AF-spouse' ' Widowed']
# ----------------------------------------------------------------------------------------------------
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %%
df_subset = df[['age','education','marital-status']]
df_subset.head()
# Out:
#    age   education       marital-status
# 0   39   Bachelors        Never-married
# 1   50   Bachelors   Married-civ-spouse
# 2   38     HS-grad             Divorced
# 3   53        11th   Married-civ-spouse
# 4   28   Bachelors   Married-civ-spouse

# %%
df_subset['age'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# ### Boxplot showcase of age versus marital-status

# %%
df_subset.boxplot(column='age',by='marital-status',figsize=(25,10))
plt.xticks(fontsize=15)
plt.xlabel("marital-status",fontsize=20)
plt.show()

# %% [markdown]
# #### strip whitespace function is called for cleaning whitespace from the data.

# %%
def strip_whitespace(s):
    return s.strip()

# %%
# Education column
df_subset['education_stripped'] = df['education'].apply(strip_whitespace)
df_subset['education'] = df_subset['education_stripped']
df_subset.drop(labels = ['education_stripped'],axis=1,inplace=True)

# Occupation column
df_subset['occupation_stripped'] = df['occupation'].apply(strip_whitespace)
df_subset['occupation']  =df_subset['occupation_stripped']
df_subset.drop(labels = ['occupation_stripped'],axis=1,inplace=True)

# %% [markdown]
# #### Conditional clauses and join them by & (AND)

# %%
df_filtered=df_subset[(df_subset['age']>=30) & (df_subset['age']<=50)]

# %%
df_filtered.head(10)
# Out:
#     age     education          marital-status         occupation
# 0    39     Bachelors           Never-married       Adm-clerical
# 1    50     Bachelors      Married-civ-spouse    Exec-managerial
# 2    38       HS-grad                Divorced  Handlers-cleaners
# 5    37       Masters      Married-civ-spouse    Exec-managerial
# 6    49           9th   Married-spouse-absent      Other-service
# 8    31       Masters           Never-married     Prof-specialty
# 9    42     Bachelors      Married-civ-spouse    Exec-managerial
# 10   37  Some-college      Married-civ-spouse    Exec-managerial
# 11   30     Bachelors      Married-civ-spouse     Prof-specialty
# 13   32    Assoc-acdm           Never-married              Sales

# %%
answer_1=df_filtered.shape[0]
answer_1
# Out:
# 16390

# %%
print("There are {} people of age between 30 and 50 in this dataset.".format(answer_1))
# Out:
# There are 16390 people of age between 30 and 50 in this dataset.

# %%
df_subset.groupby('occupation').describe()['age']
# Out:
#                     count       mean        std   min   25%   50%   75%   max
# occupation
# ?                  1843.0  40.882800  20.336350  17.0  21.0  35.0  61.0  90.0
# Adm-clerical       3770.0  36.964456  13.362998  17.0  26.0  35.0  46.0  90.0
# Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
# Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
# Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
# Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
# Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
# Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
# Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
# Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
# Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
# ...

# %%
occupation_stats= df_subset.groupby('occupation').describe()['age']

# %%
plt.figure(figsize=(15,8))
plt.barh(y=occupation_stats.index,width=occupation_stats['count'])
plt.yticks(fontsize=13)
plt.show()

# %% [markdown]
# #### Following taking sample 10 records for 2 sub dataframes on different set of columns and showing it.

# %%
df_1 = df[['age','workclass','occupation']].sample(10,random_state=101)

df_1.head(10)
# Out:
#        age   workclass          occupation
# 22357   51     Private   Machine-op-inspct
# 26009   19     Private               Sales
# 20734   40     Private     Exec-managerial
# 17695   17     Private   Handlers-cleaners
# 27908   61     Private        Craft-repair
# 27225   58           ?                   ?
# 13108   37   Local-gov       Other-service
# 27552   22     Private        Adm-clerical
# 14043   22     Private               Sales
# 30313   26           ?                   ?

# %%
df_2 = df[['education','occupation']].sample(10,random_state=101)

df_2.head(10)
# Out:
#       education          occupation
# 22357   HS-grad   Machine-op-inspct
# 26009      11th               Sales
# 20734   HS-grad     Exec-managerial
# 17695      10th   Handlers-cleaners
# 27908   7th-8th        Craft-repair

# %% [markdown]
# #### Following code merging/joining 2 data frames df1 and df2 on 'Occupation' and dropping duplicates records afterwards.

# %%
df_merged = pd.merge(df_1,df_2,on='occupation',how='inner').drop_duplicates()

df_merged
# Out:
#    age workclass          occupation education
# 0   51   Private   Machine-op-inspct   HS-grad
# 1   19   Private               Sales      11th
# 2   40   Private     Exec-managerial   HS-grad
# 3   17   Private   Handlers-cleaners      10th
# 4   61   Private        Craft-repair   7th-8th

# %% [markdown]
# #### Create 2 Pandas Series as per assignment

# %%
data_1 = [7.3, -2.5, 3.4, 1.5]
series_1 = pd.Series(data_1)

print("Series 1:")
print(series_1)
# Out:
# Series 1:
# 0    7.3
# 1   -2.5
# 2    3.4
# 3    1.5
# dtype: float64

# %%
data_2 = [-2.1, 3.6, -1.5, 4, 3.1]
series_2 = pd.Series(data_2)

print("Series 2:")
print(series_2)
# Out:
# Series 2:
# 0   -2.1
# 1    3.6
# 2   -1.5
# 3    4.0
# 4    3.1
# dtype: float64

# %% [markdown]
# #### Addition of 2 series [array]

# %%
Addseries = series_1 + series_2

print(Addseries)
# Out:
# 0    5.2
# 1    1.1
# 2    1.9
# 3    5.5
# 4    NaN
# dtype: float64

# %% [markdown]
# #### Subtraction of 2 series [array]

# %%
Subseries = series_1 - series_2

print(Subseries)
# Out:
# 0    9.4
# 1   -6.1
# 2    4.9
# 3   -2.5
# 4    NaN
# dtype: float64
